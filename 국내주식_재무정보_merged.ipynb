# %% [markdown]
# #Section 1 Library 불러오기

# %%
import OpenDartReader

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import numpy as np
import os

import warnings
warnings.filterwarnings("ignore")

import matplotlib as mpl
mpl.rc('font', family='Malgun Gothic')
mpl.rc('axes', unicode_minus=False)

# %%
api_key = ' ebb8f1391a48f6766cb70f3616e901e630e51939'  #25년 5월 31일 업데잇
dart = OpenDartReader(api_key)

# %% [markdown]
# #Section 2.1 회사를 정하고 재무제표 가져오기

# %%
#원하는 회사의 종목코드와 회사명 입력하기
corp_code = '355390'
corp_name='크라우드웍스'


path = r"D:\python_PJT\01_Data_Mart_생성\05_종목별_Data"

folder_list=os.listdir(path)

# corp_name이 폴더리스트에 없으면 폴더 만들기
if corp_name not in folder_list:
    os.makedirs(os.path.join(path, corp_name))

folder_path = os.path.join(path, corp_name)
folder_path
# Out:
# 'D:\\python_PJT\\01_Data_Mart_생성\\05_종목별_Data\\크라우드웍스'

# %%
# 지정한 회사의 재무제표를 fin_list에 담기

fin_list=[] # 재무제표를 담을 리스트
index_code=[] #인덱스에 사용할 년, 보고서 종류 담기
year=list(range(2015,2026))
rep_code = ['11013', '11012', '11014', '11011']

for yr in year:
    for rp in rep_code:
        df_t=dart.finstate_all(corp_code, yr, reprt_code=rp)
        if not df_t.empty:
            fin_list.append(df_t)
            index_code.append(str(yr)+'_'+rp)
# Out:
# reprt_code='11013', fs_div='CFS' (1분기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11012', fs_div='CFS' (반기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11014', fs_div='CFS' (3분기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11011', fs_div='CFS' (사업보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11013', fs_div='CFS' (1분기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11012', fs_div='CFS' (반기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11014', fs_div='CFS' (3분기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11011', fs_div='CFS' (사업보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11013', fs_div='CFS' (1분기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11012', fs_div='CFS' (반기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11014', fs_div='CFS' (3분기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11011', fs_div='CFS' (사업보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11013', fs_div='CFS' (1분기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11012', fs_div='CFS' (반기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11014', fs_div='CFS' (3분기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11011', fs_div='CFS' (사업보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11013', fs_div='CFS' (1분기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11012', fs_div='CFS' (반기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11014', fs_div='CFS' (3분기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11011', fs_div='CFS' (사업보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11013', fs_div='CFS' (1분기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11012', fs_div='CFS' (반기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11014', fs_div='CFS' (3분기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11011', fs_div='CFS' (사업보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11013', fs_div='CFS' (1분기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11012', fs_div='CFS' (반기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11014', fs_div='CFS' (3분기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11011', fs_div='CFS' (사업보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11013', fs_div='CFS' (1분기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11012', fs_div='CFS' (반기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11014', fs_div='CFS' (3분기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11011', fs_div='CFS' (사업보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11013', fs_div='CFS' (1분기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11012', fs_div='CFS' (반기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11014', fs_div='CFS' (3분기보고서, 연결제무제표)'
# reprt_code='11011', fs_div='CFS' (사업보고서, 연결제무제표)'
# reprt_code='11013', fs_div='CFS' (1분기보고서, 연결제무제표)'
# reprt_code='11012', fs_div='CFS' (반기보고서, 연결제무제표)'
# reprt_code='11014', fs_div='CFS' (3분기보고서, 연결제무제표)'
# reprt_code='11011', fs_div='CFS' (사업보고서, 연결제무제표)'
# reprt_code='11013', fs_div='CFS' (1분기보고서, 연결제무제표)'
# reprt_code='11012', fs_div='CFS' (반기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11014', fs_div='CFS' (3분기보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# reprt_code='11011', fs_div='CFS' (사업보고서, 연결제무제표)'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}

# %% [markdown]
# #Section 2.2 계정 이름 통일하기 (수동으로 작업해야 함)

# %%
fin_list[0]['sj_nm'].unique()
# Out:
# array(['재무상태표', '포괄손익계산서', '현금흐름표', '자본변동표'], dtype=object)

# %%
#손익계산서 리스트로 모으기
ic_list=[]  #손익계산서 list
for i in range(len(fin_list)):
    df_t =fin_list[i][ fin_list[i]['sj_nm'].isin(['포괄손익계산서', '손익계산서'])]
    df_t =df_t[['account_nm', 'thstrm_amount','bsns_year','reprt_code']]
    # df_t.index=df_t['account_nm']
    # df_t.drop(columns=['account_nm'], inplace=True)
    ic_list.append(df_t)

# %%
#손익계산서 정리를 위해 표준 account_name을 설정해야 함
#하기 프로세스를 따라서 모두 True가 나오면, 정리된 account_name을 사용하면 됨

# %%
ic_list[-1]
# Out:
#                 account_nm thstrm_amount bsns_year reprt_code
# 44                영업이익(손실)   -2772517827      2025      11013
# 45                    기타수익     351056695      2025      11013
# 46                    기타비용       2929810      2025      11013
# 47                   지분법손익         43082      2025      11013
# 48                   총포괄손익   -3386238879      2025      11013
# 49          비지배지분 귀속 총포괄손익     -82629138      2025      11013
# 50  지배기업의 소유주에게 귀속되는 총포괄손익   -3303609741      2025      11013
# 51                    영업비용    4672384516      2025      11013
# 52              기본주당이익(손실)          -374      2025      11013
# 53              희석주당이익(손실)          -374      2025      11013
# 54                    금융비용    1077667263      2025      11013
# 55                    금융수익      81282708      2025      11013
# 56                   법인세비용             0      2025      11013
# 57              기타포괄이익(손실)      34493536      2025      11013
# 58         당기손익으로 재분류되는 항목      34493536      2025      11013
# 59               해외사업장환산손익      34493536      2025      11013
# 60               당기순이익(손실)   -3420732415      2025      11013
# 61          비지배지분 귀속 당기순이익     -82629138      2025      11013
# 62  지배기업의 소유주에게 귀속되는 당기순이익   -3338103277      2025      11013
# 63         법인세비용차감전순이익(손실)   -3420732415      2025      11013
# 64                    영업수익    1899866689      2025      11013

# %%
df_income = pd.concat(ic_list, ignore_index=True)

# %%
df_income['account_nm'].unique()
# Out:
# array(['영업이익(손실)', '기타이익', '기타손실', '총포괄손익', '포괄손익, 비지배지분',
#        '포괄손익, 지배기업의 소유주에게 귀속되는 지분', '영업비용', '기본주당이익(손실)', '희석주당이익(손실)',
#        '금융원가', '금융수익', '법인세비용(수익)', '기타포괄손익', '해외사업장환산외환차이(세후기타포괄손익)',
#        '당기순이익(손실)', '비지배지분에 귀속되는 당기순이익(손실)', '지배기업의 소유주에게 귀속되는 당기순이익(손실)',
#        '법인세비용차감전순이익(손실)', '영업수익', '확정급여제도의 재측정손익(세후기타포괄손익)', '지분법손실',
#        '당기손익으로 재분류될 수 있는 항목(세후기타포괄손익)', '기타수익', '기타비용', '지분법손익',
#        '비지배지분 귀속 총고퐐손익', '지배기업의 소유주에게 귀속되는 총포괄손익', '금융비용', '법인세비용',
#        '기타포괄이익(손실)', '해외사업장환산손익', '반기순이익(손실)', '비지배지분 귀속 반기순이익',
#        '지배기업의 소유주에게 귀속되는 반기순이익', '분기손이익(손실)', '비지배지분 귀속 총포괄손익',
#        '순확정급여부채의 재측정요소', '비지배지분 귀속 당기순이익', '지배기업의 소유주에게 귀속되는 당기순이익',
#        '당기손익으로 재분류되는 항목'], dtype=object)

# %%
#계정명을 표준계정명으로 변경하고, Filtering할 파일 만들기
df_std= pd.read_excel(r'D:\python_PJT\01_Data_Mart_생성\02_Open_dart\income_nm_std.xlsx')
df_std.dropna(axis=0, inplace=True)
account_std_map=dict(zip(df_std['original'],df_std['std']))
interest_items=list(set(account_std_map.values()))
pattern = '|'.join(interest_items)
interest_items
# Out:
# ['영업이익', '기본주당순이익', '매출액', '당기순이익']

# %%
#표준계정명으로 변경, 날짜 변경하기
df_income['account_nm_std'] = df_income['account_nm'].replace(account_std_map)
reprt_code_std = {'11011':'12-31','11013':'03-31', '11012':'06-30', '11014':'09-30'}
df_income['reprt_code_std'] = df_income['reprt_code'].replace(reprt_code_std)
df_income['issue_date'] = df_income['bsns_year'] + str('-') + df_income['reprt_code_std'] 
df_income['issue_date']=pd.to_datetime(df_income['issue_date'])

# %%
#계정명 빈칸 없애기, 수정을 위해 account_nm 엑셀 활용
df_income['account_nm'] = df_income['account_nm'].str.strip().str.replace(' ', '', regex=False)
df_income['account_nm'].unique()
# Out:
# array(['영업이익(손실)', '기타이익', '기타손실', '총포괄손익', '포괄손익,비지배지분',
#        '포괄손익,지배기업의소유주에게귀속되는지분', '영업비용', '기본주당이익(손실)', '희석주당이익(손실)',
#        '금융원가', '금융수익', '법인세비용(수익)', '기타포괄손익', '해외사업장환산외환차이(세후기타포괄손익)',
#        '당기순이익(손실)', '비지배지분에귀속되는당기순이익(손실)', '지배기업의소유주에게귀속되는당기순이익(손실)',
#        '법인세비용차감전순이익(손실)', '영업수익', '확정급여제도의재측정손익(세후기타포괄손익)', '지분법손실',
#        '당기손익으로재분류될수있는항목(세후기타포괄손익)', '기타수익', '기타비용', '지분법손익',
#        '비지배지분귀속총고퐐손익', '지배기업의소유주에게귀속되는총포괄손익', '금융비용', '법인세비용',
#        '기타포괄이익(손실)', '해외사업장환산손익', '반기순이익(손실)', '비지배지분귀속반기순이익',
#        '지배기업의소유주에게귀속되는반기순이익', '분기손이익(손실)', '비지배지분귀속총포괄손익',
#        '순확정급여부채의재측정요소', '비지배지분귀속당기순이익', '지배기업의소유주에게귀속되는당기순이익',
#        '당기손익으로재분류되는항목'], dtype=object)

# %%
# 원하는 계정명만 필터링하기
df_income=df_income[df_income['account_nm_std'].isin(interest_items)]

# %%
# 피벗테이블을 이용해 다시 정리하기
df_pivot = df_income.pivot_table(
    index='issue_date',
    columns='account_nm_std',
    values='thstrm_amount',
    aggfunc='first'  # 또는 sum, mean 등 상황에 따라 선택
)

# %%
# 문자열을 숫자열로 변경하기
for name in df_pivot.columns:
    df_pivot[name] = pd.to_numeric(df_pivot[name])

# %%
#12월 연간데이터를 분기 데이터로 변경하는 사용자 함수
def december_data_change(df_pivot):
    for i,idx in zip(range(len(df_pivot)), df_pivot.index):
        if idx.month==12 and i>3:
            for j in range(len(df_pivot.columns)):
                df_pivot.iloc[i,j] =df_pivot.iloc[i,j] -df_pivot.iloc[i-1,j] -df_pivot.iloc[i-2,j] -df_pivot.iloc[i-3,j] 
        elif idx.month==12 and i<2:
            for j in range(len(df_pivot.columns)):
                df_pivot.iloc[i,j] = df_pivot.iloc[i,j]/4

# %%
december_data_change(df_pivot)
df_pivot
# Out:
# account_nm_std  기본주당순이익         당기순이익          영업이익
# issue_date
# 2023-09-30     -2704.00 -1.032956e+10 -1.810214e+09
# 2023-12-31      -645.75 -2.393317e+09 -4.464556e+08
# 2024-03-31      -741.00 -3.093471e+09 -3.003467e+09
# 2024-06-30      -560.00 -2.399242e+09 -4.329597e+09
# 2024-09-30     -1010.00 -4.306270e+09 -3.793136e+09
# 2024-12-31       212.00  6.335032e+08 -5.998967e+08
# 2025-03-31      -374.00 -3.420732e+09 -2.772518e+09

# %%
df_pivot.to_excel(f'{folder_path}\\{corp_name}_손익계산서.xlsx')

# %%
fin_list[0]['sj_nm'].unique()
# Out:
# array(['재무상태표', '포괄손익계산서', '현금흐름표', '자본변동표'], dtype=object)

# %%
#재무상태표 리스트로 모으기
ic_list=[]  
for i in range(len(fin_list)):
    df_t =fin_list[i][ fin_list[i]['sj_nm'] =='재무상태표']
    df_t =df_t[['account_nm', 'thstrm_amount','bsns_year','reprt_code']]
    # df_t.index=df_t['account_nm']
    # df_t.drop(columns=['account_nm'], inplace=True)
    ic_list.append(df_t)
df_income = pd.concat(ic_list, ignore_index=True)
df_income['account_nm'] = df_income['account_nm'].str.strip().str.replace(' ', '', regex=False)

df_income['account_nm'].unique()
# Out:
# array(['자산총계', '유동자산', '매출채권', '현금및현금성자산', '유동계약자산', '당기법인세자산', '기타유동자산',
#        '기타유동금융자산', '단기금융상품', '비유동자산', '장기금융상품', '비유동당기손익인식금융자산', '무형자산',
#        '기타비유동자산', '기타비유동금융자산', '유형자산', '사용권자산', '자본총계',
#        '지배기업의소유주에게귀속되는자본', '자본잉여금', '기타자본구성요소', '기타포괄손익누계액', '자본금',
#        '이익잉여금(결손금)', '비지배지분', '자본과부채총계', '유동부채', '미지급법인세', '단기매입채무',
#        '유동계약부채', '유동리스부채', '유동충당부채', '기타유동금융부채', '기타유동부채', '유동차입금',
#        '부채총계', '비유동부채', '전환사채', '전환상환우선주부채', '비유동파생상품부채', '퇴직급여부채',
#        '이연법인세부채', '비유동리스부채', '비유동충당부채', '비유동종업원급여충당부채', '유동파생상품자산',
#        '유동파생상품부채', '유동성신주인수권부사채', '유동성전환상환우선주부채', '관계기업에대한투자자산', '파생상품자산',
#        '계약자산', '기타금융자산', '당기손익-공정가치측정금융자산', '관계기업투자', '지배기업소유주지분',
#        '기타자본항목', '결손금', '파생상품부채', '신주인수권부사채', '당기법인세부채', '매입채무', '계약부채',
#        '리스부채', '기타충당부채', '기타금융부채', '단기차입금', '순확정급여부채', '장기종업원급여부채',
#        '매각예정비유동자산', '전환사채,총액'], dtype=object)

# %%
#계정명을 표준계정명으로 변경하고, Filtering할 파일 만들기

df_std= pd.read_excel('bal_nm_std.xlsx')
account_std_map=dict(zip(df_std['original'],df_std['std']))
interest_items=list(set(account_std_map.values()))
pattern = '|'.join(interest_items)

#표준계정명으로 변경, 날짜 변경하기
df_income['account_nm_std'] = df_income['account_nm'].replace(account_std_map)
reprt_code_std = {'11011':'12-31','11013':'03-31', '11012':'06-30', '11014':'09-30'}
df_income['reprt_code_std'] = df_income['reprt_code'].replace(reprt_code_std)
df_income['issue_date'] = df_income['bsns_year'] + str('-') + df_income['reprt_code_std'] 
df_income['issue_date']=pd.to_datetime(df_income['issue_date'])

# 원하는 계정명만 필터링하기
df_income=df_income[df_income['account_nm_std'].isin(interest_items)]

# %%
# 피벗테이블을 이용해 다시 정리하기
df_pivot = df_income.pivot_table(
    index='issue_date',
    columns='account_nm_std',
    values='thstrm_amount',
    aggfunc='first'  # 또는 sum, mean 등 상황에 따라 선택
)
df_pivot
# 문자열을 숫자열로 변경하기
for name in df_pivot.columns:
    df_pivot[name] = pd.to_numeric(df_pivot[name])
    
#12월 연간데이터를 분기 데이터로 변경하는 사용자 함수
def december_data_change(df_pivot):
    for i,idx in zip(range(len(df_pivot)), df_pivot.index):
        if idx.month==12 and i>3:
            for j in range(len(df_pivot.columns)):
                df_pivot.iloc[i,j] =df_pivot.iloc[i,j] -df_pivot.iloc[i-1,j] -df_pivot.iloc[i-2,j] -df_pivot.iloc[i-3,j] 
        elif idx.month==12 and i<2:
            for j in range(len(df_pivot.columns)):
                df_pivot.iloc[i,j] = df_pivot.iloc[i,j]/4

# december_data_change(df_pivot)
df_pivot
# Out:
# account_nm_std        무형자산         부채총계         유동자산        유형자산  \
# issue_date
# 2023-09-30      1154507586  17339252814  25393582982  2596466460
# 2023-12-31      1593093786  28148510245  35885865010  2609168487
# 2024-03-31      1679676363  27060620975  30921156996  2766070277
# 2024-06-30      1643193000  24293128031  24781211711  2804180281
# 2024-09-30      1595209640  22135508130  16130517586  2794409931
# 2024-12-31      1621699460  22549903882  20516153997   694738235
# 2025-03-31      1807619448  19510916540  14452694495   621621091
#
# account_nm_std         이익잉여금         자본금         자본총계         자산총계
# issue_date
# 2023-09-30     -5.813408e+10  4046008000  14226008494  31565261308
# 2023-12-31     -5.772527e+10  4046008000  14712478867  42860989112
# 2024-03-31     -3.221600e+09  4127071000  12204565959  39265186934
# 2024-06-30               NaN  4152100000  10141993657  34435121688
# 2024-09-30               NaN  4224606000   6434598807  28570106937
# 2024-12-31               NaN  4468968000  10315666121  32865570003
# 2025-03-31               NaN  4468968000   7208045488  26718962028

# %%
df_pivot.to_excel(f'{folder_path}\\{corp_name}_재무상태표.xlsx')

# %%
fin_list[0]['sj_nm'].unique()
# Out:
# array(['재무상태표', '포괄손익계산서', '현금흐름표', '자본변동표'], dtype=object)

# %%
#현금흐름표 리스트로 모으기
ic_list=[]  #손익계산서 list
for i in range(len(fin_list)):
    df_t =fin_list[i][ fin_list[i]['sj_nm'] =='현금흐름표']
    df_t =df_t[['account_nm', 'thstrm_amount','bsns_year','reprt_code']]
    # df_t.index=df_t['account_nm']
    # df_t.drop(columns=['account_nm'], inplace=True)
    ic_list.append(df_t)
df_income = pd.concat(ic_list, ignore_index=True)
df_income['account_nm'] = df_income['account_nm'].str.strip().str.replace(' ', '', regex=False)

df_income['account_nm'].unique()
# Out:
# array(['기초현금및현금성자산', '기말현금및현금성자산', '재무활동현금흐름', '자기주식의취득으로인한현금의유출',
#        '금융리스부채의지급', '주식선택권행사로인한현금유입', '단기차입금의증가', '단기차입금의상환',
#        '현금의기타유입(유출)', '지배력을상실하지않는종속기업에대한소유지분의변동으로인한지급',
#        '지배력을상실하지않는종속기업에대한소유지분의변동으로인한현금유입', '투자활동현금흐름', '임차보증금의감소',
#        '대여금의감소', '임차보증금의증가', '대여금의증가', '장기금융상품의처분', '단기금융상품의처분',
#        '당기손익인식금융자산의취득', '장기대여금및수취채권의취득', '단기금융상품의취득',
#        '종속기업과기타사업의지배력상실에따른현금흐름', '정부보조금의수취', '유형자산의처분', '무형자산의취득',
#        '기타장기성자산의취득', '유형자산의취득', '영업활동현금흐름', '영업으로부터창출된현금흐름', '법인세환급(납부)',
#        '이자지급(영업)', '이자수취', '현금및현금성자산에대한환율변동효과',
#        '환율변동효과반영전현금및현금성자산의순증가(감소)', '신주인수권부사채의증가', '상환우선주발행', '장기금융상품의취득',
#        '종속기업과기타사업의지배력획득에따른현금흐름', '신주발행비지급', '관계기업에대한투자자산의취득',
#        '반기말현금및현금성자산', '재무활동으로인한현금유입액', '전환사채의보통주전환', '주식매수선택권의행사',
#        '종속기업주식매수선택권의행사', '리스부채의상환', '투자활동으로인한현금흐름', '보증금의감소', '단기대여금의감소',
#        '보증금의증가', '단기대여금의증가', '단기금융상품의감소', '당기손익-공정가치측정금융자산의증가',
#        '관계기업투자의취득', '단기금융상품의증가', '장기선급금의증가', '장기대여금의감소', '장기대여금의증가',
#        '영업활동으로인한현금흐름', '법인세의환급(납부)', '이자의지급', '이자의수취', '환율변동효과',
#        '현금및현금성자산의순증감', '분기말현금및현금성자산', '종속기업추가취득', '종속기업유상증자', '자기주식의매입',
#        '합병으로인한증가', '연결범위변동', '당기말현금및현금성자산', '종속기업처분', '유상증자', '자기주식의취득',
#        '신주인수권부사채의감소', '매각예정비유동자산의처분', '당기손익-공정가치측정금융자산의처분'], dtype=object)

# %%
#계정명을 표준계정명으로 변경하고, Filtering할 파일 만들기
df_std= pd.read_excel('cash_nm_std.xlsx')
account_std_map=dict(zip(df_std['original'],df_std['std']))
interest_items=list(set(account_std_map.values()))
pattern = '|'.join(interest_items)

#표준계정명으로 변경, 날짜 변경하기
df_income['account_nm_std'] = df_income['account_nm'].replace(account_std_map)
reprt_code_std = {'11011':'12-31','11013':'03-31', '11012':'06-30', '11014':'09-30'}
df_income['reprt_code_std'] = df_income['reprt_code'].replace(reprt_code_std)
df_income['issue_date'] = df_income['bsns_year'] + str('-') + df_income['reprt_code_std'] 
df_income['issue_date']=pd.to_datetime(df_income['issue_date'])

# 원하는 계정명만 필터링하기
df_income=df_income[df_income['account_nm_std'].isin(interest_items)]

# 피벗테이블을 이용해 다시 정리하기
df_pivot = df_income.pivot_table(
    index='issue_date',
    columns='account_nm_std',
    values='thstrm_amount',
    aggfunc='first'  # 또는 sum, mean 등 상황에 따라 선택
)

# %%
# 문자열을 숫자열로 변경하기
for name in df_pivot.columns:
    df_pivot[name] = pd.to_numeric(df_pivot[name])
#12월 연간데이터를 분기 데이터로 변경하는 사용자 함수
def december_data_change(df_pivot):
    for i,idx in zip(range(len(df_pivot)), df_pivot.index):
        if idx.month==12 and i>3:
            for j in range(len(df_pivot.columns)):
                df_pivot.iloc[i,j] =df_pivot.iloc[i,j] -df_pivot.iloc[i-1,j] -df_pivot.iloc[i-2,j] -df_pivot.iloc[i-3,j] 
        elif idx.month==12 and i<2:
            for j in range(len(df_pivot.columns)):
                df_pivot.iloc[i,j] = df_pivot.iloc[i,j]/4

december_data_change(df_pivot)
df_pivot
# Out:
# account_nm_std    기말현금및현금성자산    영업활동현금흐름      재무활동현금흐름  투자활동으로인한현금흐름
# issue_date
# 2023-09-30      1.942660e+09   480912375  2.534392e+09 -3.527697e+09
# 2023-12-31      7.562514e+08  -166970452  3.119832e+09 -2.810414e+09
# 2024-03-31      3.725922e+09 -1724960656 -1.326466e+08  2.558663e+09
# 2024-06-30               NaN -4787995983           NaN  6.589792e+09
# 2024-09-30               NaN -8138647993           NaN  1.057506e+10
# 2024-12-31               NaN  4445185218           NaN -2.066702e+08
# 2025-03-31               NaN -3036205306 -2.952252e+09  2.447545e+09

# %%
df_pivot.to_excel(f'{folder_path}\\{corp_name}_현금흐름표.xlsx')
